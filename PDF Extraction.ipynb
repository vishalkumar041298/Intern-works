# %%
import fitz

# %%
import pandas as pd

# %%
file=fitz.open("P_WARD.pdf")

# %%
page=len(file)

# %%
page
# Out:
# 1

# %%
str=file.getPageText(0)

# %%
res = list(str.split("\n"))

# %%
for x in range(len(res)):
    print(res[x])
# Out:
# "S
# "S
# CRZ-III
# CRZ-II
# CRZ-II
# CRZ-II
# CRZ-II
# CRZ-III
# CRZ-
# II
# CRZ-II
# CRZ-I
# CRZ-I
# CRZ-III
# CRZ-III
# CRZ-I
# CRZ-III
# CRZ-III
# CRZ-I
# CRZ-
# I
# CRZ-I
# CRZ-I
# CRZ-II
# CRZ-I
# CRZ-I
# CRZ-I
# CRZ-I
# CRZ-I
# CRZ-II
# CRZ-III
# CRZ-I
# CRZ-II
# SAS
# G
# RAILWAY
# MARSHELING YARD
# RAILWAY
# MARSHELING
# YARD
# RG
# RG
# RM
# RM
# PG
# MAP
# RM
# WC
# RG
# G
# PG
# PG
# G
# G
# PO
# PO
# PH / HDH
# SAS
# HD
# RG
# MAP
# PH /
# HDH
# BAFHIRA
# NAGAR
# SAS
# PG
# RG
# SAS
# INTEGRATED HEALTH CARE AND HEALTH TRAINING CENTRE
# PO
# BLINDMEN
# ASSOCIATION
# HOUSING
# AMENITY
# RG
# RG
# PS
# RG
# PL
# SUB. STN.
# RG
# EDUCATIONAL
# COMPLEX
# GOVT.
# STAFF
# QRTS.
# COURT
# & COURT
# HSG.
# MAP
# PG
# GOVT.
# OFFICES
# M
# PH /
# HDH
# PS
# SUB STN.
# PO
# WARE HOUSE
# PG
# WC
# IE
# G
# PG
# IE
# IE
# SAS
# PG
# G
# G
# PG
# HSG.
# FOR
# DIS. HSD
# SAS
# PG
# MAP
# PG
# RG
# G
# RG
# +H
# PH
# G
# G
# G
# TE
# RM
# PO
# RG
# G
# WC
# RM
# G
# RG
# RD
# G
# JETTY
# ...

# %%
sur=[]
for i in res:
    if len(i)>0:
        if i[0].isdigit():
            sur.append(i)

# %%
for x in range(len(sur)):
    print(sur[x])
# Out:
# 15 % LAYOUT RG
# 15%
# 3556 (PT)REHABIL ITATED
# 6.10  M ACCESS
# 6.10 M ACCESS
# 9.15  M RO AD
# 3 6.60 M
# 18.30 M
# 13 .40 Re-Align ed DP ROAD
# 18. 30 M
# 18 .30 M
# 9.15 M
# 9.1 5 M
# 27. 45 M
# 18.30
# 1 3.4 0 M
# 18 .30 M
# 1 8 . 3 0
# 9.1 5 M
# 13 .40 M
# 12 .00 M
# 18 .30 M
# 18.3 0 M
# 18. 30 M
# 9.1 5 M
# 9 .15 M
# 45. 70 M
# 36 .60
# 9. 15 M
# 1 8.3 0 M
# 18 .30 M
# 9.1 5M
# 18.3 0 M
# 45 .70 M
# 13.4 0 Re -Aligned DP ROAD
# 13. 40 M
# 6.10 M
# 18.3 0 M
# 18 .30 M
# 1 8.30 M
# 9. 15 M
# 13 .40 M
# 13. 40 M
# 24C
# 22A
# 26
# 31B
# 31C
# 32F
# 32E
# 32D
# 34
# 36A
# 35
# 37
# 42
# 41
# 40
# 5B
# 9
# 10
# 6
# 8
# 7
# 5A
# 3
# 2B
# 2A
# 1
# 4
# 28A
# 20
# 21
# 31A
# 23A
# 23C
# 23B
# 19C
# 19A
# 18A
# 18B
# 12
# 16
# 15
# 38B
# 33B
# 33A
# 14
# 23D
# 22B
# 27
# 13
# 58
# 73A
# 73B
# 74
# 75A
# 75B
# 76A
# 76B
# 71
# 70
# 68&69
# 67
# 66
# 65
# 64
# 63
# 62
# 61
# 56
# 38A
# 59
# 60
# 55F
# 55C
# 55G
# 55B
# 55E
# 55D
# 54
# 55A
# 51- 52
# 50
# 49
# 48
# 47
# 46
# 45B
# 43
# ...

# %%
survey=[i for i in sur if not ('.' in i or '°' in i or '%' in i or '(' in i)]

# %%
len(survey)
# Out:
# 16613

# %%
for x in range(len(survey)):
    print(survey[x])
# Out:
# 24C
# 22A
# 26
# 31B
# 31C
# 32F
# 32E
# 32D
# 34
# 36A
# 35
# 37
# 42
# 41
# 40
# 5B
# 9
# 10
# 6
# 8
# 7
# 5A
# 3
# 2B
# 2A
# 1
# 4
# 28A
# 20
# 21
# 31A
# 23A
# 23C
# 23B
# 19C
# 19A
# 18A
# 18B
# 12
# 16
# 15
# 38B
# 33B
# 33A
# 14
# 23D
# 22B
# 27
# 13
# 58
# 73A
# 73B
# 74
# 75A
# 75B
# 76A
# 76B
# 71
# 70
# 68&69
# 67
# 66
# 65
# 64
# 63
# 62
# 61
# 56
# 38A
# 59
# 60
# 55F
# 55C
# 55G
# 55B
# 55E
# 55D
# 54
# 55A
# 51- 52
# 50
# 49
# 48
# 47
# 46
# 45B
# 43
# 29B
# 29C
# 29D
# 30
# 29A
# 28B
# 173
# 219
# 31
# 51
# 2379
# 2279
# 2280
# 1746
# 3204
# 2386
# 2465
# 2483
# 57
# 58
# 55
# 53
# 44
# 43
# 42
# 41
# 39
# 38
# 37
# 248
# 249
# 262
# 747
# 760
# 759
# 758
# 755
# 754
# 727
# 2278
# 2280
# 2293
# 2292
# 2300
# 2291
# 2299
# 2301
# 2302
# 2325
# 2324
# 2326
# 2327
# 2323
# 2307
# 2438
# 1492
# 1554
# 1555
# 1553
# 94
# 907
# 642
# 641
# 640 639
# 637
# 636
# 635
# 634
# 633
# 632
# 631
# 587
# 588
# 144
# 217
# 216
# 215
# 149
# 81
# 541
# 539
# 537
# 547
# 111
# 22
# ...

# %%
File = open("P_ward.csv","w")
File.close()

 
for entries in survey :
    File = open("P_ward.csv","a")
    File.write(entries)
    File.write("\n")
    File.close()

# %%
names=["Akse","Akurdi","Akurli","Ambivali","Andheri","Anik","Are","Asalpha","Badhavan","Bandivali","Bandra","Bapanale","Belapur","Bhandup","Boli","Borala","Borivali","Bramhanvada","Chakala","Chandivali","Charkop","Chembur","Chinchavali","Chincholi","Chinchwad","Chuing","Dahisar","Danda","Daravali","Darave","Dehugaon","Dehurod-Cantonment","Devanar","Dindoshi","Divale","Eksar","Erangal","Ghatkopar","Gorai","Goregaon","Gundavali","Gundavali Gundavali ","Gundgaon","Hariyali","Ismaliya","Juhu","Kandivali","Kanheri","Kanjur","Karave","Khari","Kinhai","Kirol","Kiwale","Klarebad","Kolekalyan","Kondivita","Kopari","Kukashet","Kurar","Kurla","Madh","Magathane","Mahul","Majas","Malad","Malavani","Malinagar","Mamuradi","Manbudruk","Mandale","Mandaneshwar","Mandapeshwar","Mankhurd","Manori","Maravali","Marol","Maroshi","Marve","Mogara","Mohili","Mulgaon","Mulund","Nagathane","Nahur","Nanole","Nerul","Nigadi","Oshivara","pahadi goregaon","Parajapur","Parighakhar","Pasapoli","Pavai","Pi.ena.pahadieksar","Poisar","Rahatani/kalewadi","Ravet","Sahar","Sai","Saki","Sanapada","Santakrujh","Sarsole","Shahabaj","Shimpavali","Shiravane","Sonkhar","Tirandaj","Tulasi","Tungaona","Turbhe","Vadhavali","Vadhavan","Valnai","Varsova","Vikroli","Vileparle","Viththalanagar"]

# %%
bignames=[]
for string in names:
    bignames.append(string.upper())

# %%
bignames
# Out:
# ['AKSE',
#  'AKURDI',
#  'AKURLI',
#  'AMBIVALI',
#  'ANDHERI',
#  'ANIK',
#  'ARE',
#  'ASALPHA',
#  'BADHAVAN',
#  'BANDIVALI',
#  'BANDRA',
#  'BAPANALE',
#  'BELAPUR',
#  'BHANDUP',
#  'BOLI',
#  'BORALA',
#  'BORIVALI',
#  'BRAMHANVADA',
#  'CHAKALA',
#  'CHANDIVALI',
#  'CHARKOP',
#  'CHEMBUR',
#  'CHINCHAVALI',
#  'CHINCHOLI',
#  'CHINCHWAD',
#  'CHUING',
#  'DAHISAR',
#  'DANDA',
#  'DARAVALI',
#  'DARAVE',
#  'DEHUGAON',
#  'DEHUROD-CANTONMENT',
#  'DEVANAR',
#  'DINDOSHI',
#  'DIVALE',
#  'EKSAR',
#  'ERANGAL',
#  'GHATKOPAR',
#  'GORAI',
#  'GOREGAON',
#  'GUNDAVALI',
#  'GUNDAVALI GUNDAVALI ',
#  'GUNDGAON',
#  'HARIYALI',
#  'ISMALIYA',
#  'JUHU',
#  'KANDIVALI',
#  'KANHERI',
#  'KANJUR',
#  'KARAVE',
#  'KHARI',
#  'KINHAI',
#  'KIROL',
#  'KIWALE',
#  'KLAREBAD',
#  'KOLEKALYAN',
#  'KONDIVITA',
#  'KOPARI',
#  'KUKASHET',
#  'KURAR',
#  'KURLA',
#  'MADH',
#  'MAGATHANE',
#  'MAHUL',
#  'MAJAS',
#  'MALAD',
#  'MALAVANI',
#  'MALINAGAR',
#  'MAMURADI',
# ...

# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
match=[]
for i in bignames:
    for j in res:
        if fuzz.ratio(i,j)>75:
        
#         if fuzz.partial_ratio(i,j)>90:
            
            match.append(i)

# %%
villagenames= list(dict.fromkeys(match))

# %%
villagenames
# Out:
# ['AKSE',
#  'CHINCHAVALI',
#  'CHINCHOLI',
#  'CHUING',
#  'DARAVALI',
#  'DINDOSHI',
#  'EKSAR',
#  'ERANGAL',
#  'GOREGAON',
#  'KURAR',
#  'KURLA',
#  'MALAD',
#  'MALAVANI',
#  'MANORI',
#  'MARAVALI',
#  'MARVE',
#  'OSHIVARA',
#  'PAHADI GOREGAON',
#  'SAI',
#  'VALNAI']

# %%
len(villagenames)
# Out:
# 20

# %%
# villagenames=[]
# for name in bignames:
#     for i in res:
#         if (name in i):
#             villagenames.append(name)

# %%
x=[None]*(len(survey)-len(villagenames))

# %%
villagenames=villagenames+x

# %%
len(villagenames)
# Out:
# 16613

# %%
df = pd.DataFrame(columns =['village', 'surveynumbers'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [village, surveynumbers]
# Index: []

# %%
df['village'],df['surveynumbers']=villagenames,survey

# %%
df
# Out:
#            village surveynumbers
# 0             AKSE           24C
# 1      CHINCHAVALI           22A
# 2        CHINCHOLI            26
# 3           CHUING           31B
# 4         DARAVALI           31C
# ...            ...           ...
# 16608         None           693
# 16609         None           692
# 16610         None           698
# 16611         None           172
# 16612         None          2407
#
# [16613 rows x 2 columns]

# %%
df.to_csv("P_ward villages and surevy",index=False)
